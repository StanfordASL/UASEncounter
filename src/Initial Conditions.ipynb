# %%
import HDF5, JLD
using EncounterVisualization
import PyPlot
# Out:
# INFO: Loading help data...

# %%
data = JLD.load("../data/box_10k_collisions.ic")
ics = data["ics"]
PyPlot.clf()
ax = PyPlot.gca()
for ic in ics
    vehicle_arrow(ax, ic.is, scale=60)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f8f3dfaf0d0>)

# %%
data = JLD.load("../data/box_10k_mixed.ic")
ics = data["ics"]
PyPlot.clf()
ax = PyPlot.gca()
for ic in ics
    vehicle_arrow(ax, ic.is, scale=60)
end
vehicle_arrow(ax,[0.0,0.0,0.0],color="g")
PyPlot.xlabel("y (East)")
PyPlot.ylabel("x (North)")
PyPlot.scatter(0.0,1000,color="r")
PyPlot.axis("equal")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f8efa3c49d0>)
# (-1500.0,1500.0,-1000.0,2000.0)

# %%
# using PyPlot
# savefig("intruderics.png")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f8f03c5ae10>)

# %%
data = JLD.load("../data/10k_collisions.ic")
ics = data["ics"]
PyPlot.clf()
ax = PyPlot.gca()
for ic in ics
    vehicle_arrow(ax, ic.is, scale=60)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f317562a550>)

# %%
data = JLD.load("../data/10k_mixed.ic")
ics = data["ics"]
PyPlot.clf()
ax = PyPlot.gca()
for ic in ics
    vehicle_arrow(ax, ic.is, scale=60)
end
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f317480a150>)
